# %%
import pandas as pd

# %%
data = pd.read_csv("stats.csv")

# %%
data.head()
# Out:
#    problem_id   model prompt_detail  temp   i  levenshtein distance
# 0           1  gpt3.5             L   0.3   1                    14
# 1           1  gpt3.5             L   0.3   2                    14
# 2           1  gpt3.5             L   0.3  11                    14
# 3           1  gpt3.5             L   0.3  19                    14
# 4           1  gpt3.5             L   0.3  40                    14

# %%
data['problem_id'].unique()
# Out:
# array([ 1,  2,  3,  4,  5,  6,  8, 13, 14, 15, 17, 18, 23, 24,  7,  9, 10,
#        11, 12, 16, 19, 20, 21, 22, 25])

# %%
print(data.groupby(["model"]).count()['problem_id'].to_latex())
# Out:
# \begin{tabular}{lr}
# \toprule
#  & problem_id \\
# model &  \\
# \midrule
# gemini & 51 \\
# gpt3.5 & 1039 \\
# gpt4 & 149 \\
# llama & 221 \\
# mistral & 32191 \\
# \bottomrule
# \end{tabular}

# %%
data.groupby(["model", "problem_id"]).describe()
# Out:
#                       temp                                                \
#                      count      mean       std  min   25%  50%  75%  max
# model   problem_id
# gemini  23             1.0  1.000000       NaN  1.0  1.00  1.0  1.0  1.0
#         24            50.0  0.588000  0.312096  0.1  0.30  0.7  0.7  1.0
# gpt3.5  1            547.0  0.564717  0.320396  0.1  0.30  0.5  1.0  1.0
#         2            132.0  0.812879  0.207274  0.3  0.70  1.0  1.0  1.0
#         3             77.0  0.872727  0.177435  0.5  0.70  1.0  1.0  1.0
#         4            127.0  0.843307  0.199440  0.3  0.70  1.0  1.0  1.0
#         5             88.0  0.830682  0.218857  0.3  0.70  1.0  1.0  1.0
#         6             65.0  0.893846  0.159958  0.5  0.70  1.0  1.0  1.0
#         13             1.0  0.700000       NaN  0.7  0.70  0.7  0.7  0.7
#         15             1.0  0.700000       NaN  0.7  0.70  0.7  0.7  0.7
#         17             1.0  1.000000       NaN  1.0  1.00  1.0  1.0  1.0
# ...
